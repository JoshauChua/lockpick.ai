# %%
import pandas as pd

df = pd.read_csv("orders.csv")

# %%
product_and_country = df.loc[:, ["Product", "Country"]]

# %%
print(product_and_country)
# Out:
#                   Product       Country
# 0                  Laptop           USA
# 1              Headphones        Canada
# 2            Office Chair           UAE
# 3               Desk Lamp     Singapore
# 4                Keyboard        Mexico
# 5                Notebook           UAE
# 6           Standing Desk            UK
# 7                 Monitor   South Korea
# 8                     Pen         Italy
# 9                   Mouse         Japan
# 10                 Webcam        France
# 11           File Cabinet         India
# 12                Stapler     Australia
# 13              USB Drive         Spain
# 14              Bookshelf         China
# 15          Printer Paper         Egypt
# 16         Wireless Mouse        Poland
# 17         Desk Organizer           USA
# 18             Calculator         Japan
# 19             Whiteboard  Saudi Arabia
# 20           Highlighters        Canada
# 21      Bluetooth Speaker        Brazil
# ...

# %%
print(df.loc[:, ["Product", "Country"]].tail())
# Out:
#                Product      Country
# 35  Desk Lamp with USB           UK
# 36    Wireless Earbuds     Portugal
# 37            Desk Pad         Iran
# 38         Power Strip  South Korea
# 39          Desk Clock      Ukraine

# %%
df.info
# Out:
# <bound method DataFrame.info of     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df["Country"]
# Out:
# 0              USA
# 1           Canada
# 2              UAE
# 3        Singapore
# 4           Mexico
# 5              UAE
# 6               UK
# 7      South Korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             USA
# 18           Japan
# 19    Saudi Arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South Korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             USA
# 34           Japan
# 35              UK
# 36        Portugal
# 37            Iran
# 38     South Korea
# 39         Ukraine
# Name: Country, dtype: object

# %%
df[["Country", "Product"]] #using the dataframe df, we are simply printing out 2 columns with every row, 
                           #if we wanted specific rows, we use loc
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
df.loc[6:7, ["Product", "Country"]] #loc, slicing is inclusive
# Out:
#          Product      Country
# 6  Standing Desk           UK
# 7        Monitor  South Korea

# %%
df.iloc[6:8, 6:8] #iloc, note: when slicing with iloc, both positions are exclusive
# Out:
#     OrderDate Shipped
# 6  2024-06-08     Yes
# 7  2024-06-09      No

# %%
more1 = df[df["Quantity"] > 1] #filtering using booleans

# %%
df[df["Category"] == "Electronics"]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# 25     1026      Chloe Dubois     Paper Shredder  Electronics         1
# ...

# %%
df[(df["Category"] == "Electronics") & (df["Country"] == "Brazil")]
# Out:
#     OrderID    CustomerName            Product     Category  Quantity  Price  \
# 21     1022  Isabella Silva  Bluetooth Speaker  Electronics         1   95.0
#
#      OrderDate Shipped Country
# 21  2024-06-23     Yes  Brazil

# %%
more1.sort_values("Price", ascending=False) #simple sorting
# Out:
#     OrderID     CustomerName         Product     Category  Quantity  Price  \
# 7      1008       James Park         Monitor  Electronics         2  220.0
# 11     1012        Raj Patel    File Cabinet    Furniture         2  180.0
# 1      1002        Sarah Lee      Headphones  Electronics         2  150.0
# 4      1005    Carlos Mendez        Keyboard  Electronics         2   80.0
# 3      1004       Alice Wong       Desk Lamp    Furniture         3   45.0
# 16     1017    Anna Kowalski  Wireless Mouse  Electronics         2   45.0
# 22     1023   Oliver Schmidt    Office Plant    Furniture         2   35.0
# 13     1014  Diego Rodriguez       USB Drive  Electronics         5   25.0
# 38     1039       Daniel Kim     Power Strip  Electronics         2   18.0
# 12     1013      Emma Wilson         Stapler   Stationery         3   12.0
# 15     1016     Ahmed Hassan   Printer Paper   Stationery        20    8.0
# ...

# %%
df["price_per_item"] = df["Price"] / df["Quantity"]
df["price_per_item"] #adding and modifying columns, making new column derived from the division of 2 other columns
# Out:
# 0     1200.000000
# 1       75.000000
# 2      300.000000
# 3       15.000000
# 4       40.000000
# 5        1.000000
# 6      450.000000
# 7      110.000000
# 8        0.150000
# 9       35.000000
# 10      85.000000
# 11      90.000000
# 12       4.000000
# 13       5.000000
# 14     280.000000
# 15       0.400000
# 16      22.500000
# 17      65.000000
# 18      15.000000
# 19     120.000000
# 20       0.437500
# 21      95.000000
# 22      17.500000
# 23       0.266667
# 24      28.000000
# 25      75.000000
# 26      22.000000
# 27       0.208333
# 28     110.000000
# 29      18.000000
# 30      32.000000
# 31     140.000000
# 32      42.000000
# 33       0.008000
# 34      55.000000
# 35      68.000000
# 36     125.000000
# 37      28.000000
# 38       9.000000
# 39      35.000000
# Name: price_per_item, dtype: float64

# %%
df.fillna({"Product": "Headphone"}, inplace=True) #replacing data
df
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith             Headphones  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
group = df.groupby("Country")["Price"].sum()
group.sort_values(ascending=False)
# Out:
# Country
# USA             1265.8
# UK               518.0
# South Korea      348.0
# UAE              305.0
# China            280.0
# India            180.0
# Germany          175.0
# France           160.0
# Canada           153.5
# Portugal         125.0
# Saudi Arabia     120.0
# Japan            105.0
# Brazil            95.0
# Mexico            80.0
# Singapore         45.0
# Poland            45.0
# Colombia          42.0
# Ukraine           35.0
# Morocco           32.0
# Sweden            28.0
# Iran              28.0
# Spain             25.0
# Argentina         22.0
# Italy             19.5
# Australia         12.0
# Egypt              8.0
# Pakistan           4.0
# Russia             2.5
# Name: Price, dtype: float64

# %%
df.groupby("Country")["Price"].sum().sort_values(ascending=False)
# Out:
# Country
# USA             1265.8
# UK               518.0
# South Korea      348.0
# UAE              305.0
# China            280.0
# India            180.0
# Germany          175.0
# France           160.0
# Canada           153.5
# Portugal         125.0
# Saudi Arabia     120.0
# Japan            105.0
# Brazil            95.0
# Mexico            80.0
# Singapore         45.0
# Poland            45.0
# Colombia          42.0
# Ukraine           35.0
# Morocco           32.0
# Sweden            28.0
# Iran              28.0
# Spain             25.0
# Argentina         22.0
# Italy             19.5
# Australia         12.0
# Egypt              8.0
# Pakistan           4.0
# Russia             2.5
# Name: Price, dtype: float64

# %%
df.shape
# Out:
# (40, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith             Headphones  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...
